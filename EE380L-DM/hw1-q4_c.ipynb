# %%
# Name: Gabe Eapen
# UT EID: eapengp
# PS1 - Q4c

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import linalg
# Y = 3x
def f_noise(x):
    """f(x)+noise"""
    return x + (0.2 * np.random.randn())

def f(x,m,c):
    """f(x) = mx + c"""
    return m*x + c

# %%
#k=2 points
k = 2
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])

# %%
# http://docs.scipy.org/doc/numpy-1.10.0/reference/generated/numpy.linalg.lstsq.html#numpy.linalg.lstsq
#X = np.array([0, 1, 2, 3])
#Y = np.array([0, 1, 2, 3])
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y)[0]
print m, c
# Out:
# 1.01117019406 -0.0635816577271

# %%
xSamples = np.linspace(-2, 2, 100)
#print type(xSamples)
Y_Lsqr = np.array([f(x,m,c) for x in xSamples])
#print type(Y_Lsqr)

# %%
#plot generated Points and best fit line using Least Squares K=2
plt.plot(X, Y, 'ro')
plt.plot(xSamples, Y_Lsqr, 'b-')
plt.grid(True)
plt.title("K=2 points")
plt.show()

# %%
#k=5 points
k = 5
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y)[0]
print m, c
# Out:
# 1.30773383779 -0.144496392703

# %%
xSamples = np.linspace(-3, 2, 100)
Y_Lsqr = np.array([f(x,m,c) for x in xSamples])

# %%
#plot generated Points and best fit line using Least Squares K=5
plt.plot(X, Y, 'ro')
plt.plot(xSamples, Y_Lsqr, 'b-')
plt.grid(True)
plt.title("K=5 points")
plt.xlim(-2.5, 2)
plt.ylim(-2.5, 2)
plt.show()

# %%
#k=10 points
k = 10
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y)[0]
print m, c
# Out:
# 1.04086636991 0.00982848306022

# %%
xSamples = np.linspace(-3, 2, 100)
Y_Lsqr = np.array([f(x,m,c) for x in xSamples])

# %%
#plot generated Points and best fit line using Least Squares K=10
plt.plot(X, Y, 'ro')
plt.plot(xSamples, Y_Lsqr, 'b-')
plt.grid(True)
plt.title("K=10 points")
plt.xlim(-2.5, 2)
plt.ylim(-2.5, 2)
plt.show()

# %%
#k=11 points
k = 11
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y)[0]
print m, c
# Out:
# 1.02476221746 -0.0485833092074

# %%
xSamples = np.linspace(-3, 2, 100)
Y_Lsqr = np.array([f(x,m,c) for x in xSamples])

# %%
#plot generated Points and best fit line using Least Squares K=11
plt.plot(X, Y, 'ro')
plt.plot(xSamples, Y_Lsqr, 'b-')
plt.grid(True)
plt.title("K=11 points")
plt.xlim(-2.5, 2)
plt.ylim(-2.5, 2)
plt.show()

# %%
#k=15 points
k = 15
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y)[0]
print m, c
# Out:
# 1.03103099875 0.00726042013365

# %%
xSamples = np.linspace(-3, 2, 100)
Y_Lsqr = np.array([f(x,m,c) for x in xSamples])

# %%
#plot generated Points and best fit line using Least Squares K=15
plt.plot(X, Y, 'ro')
plt.plot(xSamples, Y_Lsqr, 'b-')
plt.grid(True)
plt.title("K=15 points")
plt.xlim(-2.5, 2)
plt.ylim(-2.5, 2)
plt.show()

# %%
#k=25 points
k = 25
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y)[0]
print m, c
# Out:
# 1.05839892253 0.0235467255215

# %%
xSamples = np.linspace(-3, 2, 100)
Y_Lsqr = np.array([f(x,m,c) for x in xSamples])

# %%
#plot generated Points and best fit line using Least Squares K=25
plt.plot(X, Y, 'ro')
plt.plot(xSamples, Y_Lsqr, 'b-')
plt.grid(True)
plt.title("K=25 points")
plt.xlim(-2.5, 2)
plt.ylim(-2.5, 2)
plt.show()

# %%
# Now fit a polynomial
# k = 2
k = 2
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
#print X, Y
# try 2 and 1 dimensional polynomial
p10 = np.poly1d(np.polyfit(X, Y, 10))
p11 = np.poly1d(np.polyfit(X, Y, 11))
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda2\lib\site-packages\numpy\lib\polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
#plot generated Points (k=2)
part_a, = plt.plot(X,Y,'ro')
plt.grid(True)
plt.title("K=2 points")
plt.xlim(-2, 3)
plt.ylim(-5, 3)
plt.show()

# %%
#plot generated Points and best fit line
xSamples = np.linspace(-8, 8, 100)
plt.plot(X, Y, 'ro')
plt.plot(xSamples, p10(xSamples), 'r--')
plt.plot(xSamples, p11(xSamples), 'b-')
plt.grid(True)
plt.title("K=2 points. Best fit degree = 10, 11")
plt.xlim(-8, 8)
plt.ylim(-8000, 8000)
plt.text(3.6,-2000,'deg=10')
plt.text(3.6,4000,'deg=11')
plt.show()

# %%
# Now fit a polynomial
# k = 5
k = 5
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
#print X, Y
# try 2 and 1 dimensional polynomial
p10 = np.poly1d(np.polyfit(X, Y, 10))
p11 = np.poly1d(np.polyfit(X, Y, 11))
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda2\lib\site-packages\numpy\lib\polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
#plot generated Points (k=5)
part_a, = plt.plot(X,Y,'ro')
plt.grid(True)
plt.title("K=5 points")
plt.xlim(-2, 3)
plt.ylim(-5, 3)
plt.show()

# %%
#plot generated Points and best fit line
xSamples = np.linspace(-8, 8, 100)
plt.plot(X, Y, 'ro')
plt.plot(xSamples, p10(xSamples), 'r--')
plt.plot(xSamples, p11(xSamples), 'b-')
plt.grid(True)
plt.title("K=5 points. Best fit degree = 10, 11")
plt.xlim(-8, 8)
plt.ylim(-8000, 8000)
plt.text(3.2,4000,'deg=10')
plt.text(3.2,-4000,'deg=11')
plt.show()

# %%
# Now fit a polynomial
# k = 10
k = 10
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
#print X, Y
# try 2 and 1 dimensional polynomial
p10 = np.poly1d(np.polyfit(X, Y, 10))
p11 = np.poly1d(np.polyfit(X, Y, 11))
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda2\lib\site-packages\numpy\lib\polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
#plot generated Points (k=10)
part_a, = plt.plot(X,Y,'ro')
plt.grid(True)
plt.title("K=10 points")
plt.xlim(-2, 3)
plt.ylim(-5, 3)
plt.show()

# %%
#plot generated Points and best fit line
xSamples = np.linspace(-8, 8, 100)
plt.plot(X, Y, 'ro')
plt.plot(xSamples, p10(xSamples), 'r--')
plt.plot(xSamples, p11(xSamples), 'b-')
plt.grid(True)
plt.title("K=10 points. Best fit degree = 10, 11")
plt.xlim(-8, 8)
plt.ylim(-8000, 8000)
#plt.text(-5,-3000,'deg=10')
#plt.text(-5,3000,'deg=11')
plt.show()

# %%
# Now fit a polynomial
# k = 11
k = 11
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
#print X, Y
# try 2 and 1 dimensional polynomial
p10 = np.poly1d(np.polyfit(X, Y, 10))
p11 = np.poly1d(np.polyfit(X, Y, 11))
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
#plot generated Points (k=11)
part_a, = plt.plot(X,Y,'ro')
plt.grid(True)
plt.title("K=11 points")
plt.xlim(-2, 3)
plt.ylim(-5, 3)
plt.show()

# %%
#plot generated Points and best fit line
xSamples = np.linspace(-8, 8, 100)
plt.plot(X, Y, 'ro')
plt.plot(xSamples, p10(xSamples), 'r--')
plt.plot(xSamples, p11(xSamples), 'b-')
plt.grid(True)
plt.title("K=11 points. Best fit degree = 10, 11")
plt.xlim(-8, 8)
plt.ylim(-8000, 8000)
#plt.text(-5,-3000,'deg=10')
#plt.text(-5,3000,'deg=11')
plt.show()

# %%
# Now fit a polynomial
# k = 15
k = 15
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
#print X, Y
# try 2 and 1 dimensional polynomial
p10 = np.poly1d(np.polyfit(X, Y, 10))
p11 = np.poly1d(np.polyfit(X, Y, 11))

# %%
#plot generated Points (k=15)
part_a, = plt.plot(X,Y,'ro')
plt.grid(True)
plt.title("K=15 points")
plt.xlim(-2, 3)
plt.ylim(-5, 3)
plt.show()

# %%
#plot generated Points and best fit line
xSamples = np.linspace(-8, 8, 100)
plt.plot(X, Y, 'ro')
plt.plot(xSamples, p10(xSamples), 'r--')
plt.plot(xSamples, p11(xSamples), 'b-')
plt.grid(True)
plt.title("K=15 points. Best fit degree = 10, 11")
plt.xlim(-8, 8)
plt.ylim(-8000, 8000)
plt.text(2.4,2000,'deg=10')
plt.text(2,-4000,'deg=11')
plt.show()

# %%
# Now fit a polynomial
# k = 25
k = 25
X = np.random.randn(k)
Y = np.array([f_noise(x) for x in X])
#print X, Y
# try 2 and 1 dimensional polynomial
p10 = np.poly1d(np.polyfit(X, Y, 10))
p11 = np.poly1d(np.polyfit(X, Y, 11))

# %%
#plot generated Points (k=25)
part_a, = plt.plot(X,Y,'ro')
plt.grid(True)
plt.title("K=25 points")
plt.xlim(-2, 3)
plt.ylim(-5, 3)
plt.show()

# %%
#plot generated Points and best fit line
xSamples = np.linspace(-8, 8, 100)
plt.plot(X, Y, 'ro')
plt.plot(xSamples, p10(xSamples), 'r--')
plt.plot(xSamples, p11(xSamples), 'b-')
plt.grid(True)
plt.title("K=10 points. Best fit degree = 10, 11")
plt.xlim(-8, 8)
plt.ylim(-8000, 8000)
plt.text(-3.1,4000,'deg=10')
plt.text(-3.2,-4000,'deg=11')
plt.show()
