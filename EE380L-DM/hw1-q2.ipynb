# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('electric.dat', sep='\s+')
df.shape
# Out:
# (96, 7)

# %%
#print(df.columns)

# %%
df.head(n=2)
# Out:
#   City  Grade  treated.Pretest  treated.Posttest  control.Pretest  \
# 0    F      1             13.8              48.9             12.3
# 1    F      1             16.5              70.5             14.4
#
#    control.Posttest Supplement?
# 0              52.3           S
# 1              55.0           R

# %%
sup_df = df[(df["Supplement?"] == 'S')]
sup_df.shape
# Out:
# (61, 7)

# %%
part_a, = plt.plot(sup_df["control.Posttest"],sup_df["treated.Posttest"],'gs')
plt.grid(True)
plt.ylabel("treated.Posttest")
plt.xlabel("control.Posttest")
plt.title("'Supplement' Group")
plt.axis([40,120,40,125])

# Add y=x
plt.plot([40,130],[40,130], 'b-')
plt.show()
sample_avg = (sup_df["treated.Posttest"] - sup_df["control.Posttest"]).mean()
# Print Sample Average
print("sample average of 'Treated.Posttest - Control.Posttest' is: {}.".format(round(sample_avg,10)))
# Out:
# sample average of 'Treated.Posttest - Control.Posttest' is: 4.8245901639.

# %%
rep_df = df[(df["Supplement?"] == 'R')]
rep_df.shape
# Out:
# (35, 7)

# %%
part_b, = plt.plot(rep_df["control.Posttest"],rep_df["treated.Posttest"],'rs')
plt.grid(True)
plt.ylabel("treated.Posttest")
plt.xlabel("control.Posttest")
plt.title("'Replacement' Group")
plt.axis([40,120,40,125])

# Add y=x
plt.plot([40,130],[40,130], 'b-')
plt.show()
sample_avg = (rep_df["treated.Posttest"] - rep_df["control.Posttest"]).mean()
# Print Sample Average
print("sample average of 'Treated.Posttest - Control.Posttest' is: {}.".format(round(sample_avg,10)))
# Out:
# sample average of 'Treated.Posttest - Control.Posttest' is: 7.1085714286.

# %%
rep_df_gr1 = rep_df[(rep_df["Grade"] == 1)]
rep_df_gr2 = rep_df[(rep_df["Grade"] == 2)]
rep_df_gr3 = rep_df[(rep_df["Grade"] == 3)]
rep_df_gr4 = rep_df[(rep_df["Grade"] == 4)]

# %%
part_d_gr1, = plt.plot(rep_df_gr1["control.Posttest"],rep_df_gr1["treated.Posttest"],'gs')
plt.grid(True)
plt.ylabel("treated.Posttest")
plt.xlabel("control.Posttest")
plt.title("'Replacement' Group - GR1")
plt.axis([40,120,40,125])

# Add y=x
plt.plot([40,130],[40,130], 'b-')
plt.show()
sample_avg = (rep_df_gr1["treated.Posttest"] - rep_df_gr1["control.Posttest"]).mean()
# Print Sample Average
print("sample average of 'Treated.Posttest - Control.Posttest' is: {}.".format(round(sample_avg,10)))
# Out:
# sample average of 'Treated.Posttest - Control.Posttest' is: 9.9857142857.

# %%
part_d_gr2, = plt.plot(rep_df_gr2["control.Posttest"],rep_df_gr2["treated.Posttest"],'rs')
plt.grid(True)
plt.ylabel("treated.Posttest")
plt.xlabel("control.Posttest")
plt.title("'Replacement' Group - GR2")
plt.axis([40,120,40,125])

# Add y=x
plt.plot([40,130],[40,130], 'b-')
plt.show()
sample_avg = (rep_df_gr2["treated.Posttest"] - rep_df_gr2["control.Posttest"]).mean()
# Print Sample Average
print("sample average of 'Treated.Posttest - Control.Posttest' is: {}.".format(round(sample_avg,10)))
# Out:
# sample average of 'Treated.Posttest - Control.Posttest' is: 9.4214285714.

# %%
part_d_gr3, = plt.plot(rep_df_gr3["control.Posttest"],rep_df_gr3["treated.Posttest"],'ys')
plt.grid(True)
plt.ylabel("treated.Posttest")
plt.xlabel("control.Posttest")
plt.title("'Replacement' Group - GR3")
plt.axis([40,120,40,125])

# Add y=x
plt.plot([40,130],[40,130], 'b-')
plt.show()
sample_avg = (rep_df_gr3["treated.Posttest"] - rep_df_gr3["control.Posttest"]).mean()
# Print Sample Average
print("sample average of 'Treated.Posttest - Control.Posttest' is: {}.".format(round(sample_avg,10)))
# Out:
# sample average of 'Treated.Posttest - Control.Posttest' is: 4.0.

# %%
part_d_gr4, = plt.plot(rep_df_gr4["control.Posttest"],rep_df_gr4["treated.Posttest"],'ks')
plt.grid(True)
plt.ylabel("treated.Posttest")
plt.xlabel("control.Posttest")
plt.title("'Replacement' Group - GR4")
plt.axis([40,120,40,125])

# Add y=x
plt.plot([40,130],[40,130], 'b-')
plt.show()
sample_avg = (rep_df_gr4["treated.Posttest"] - rep_df_gr4["control.Posttest"]).mean()
# Print Sample Average
print("sample average of 'Treated.Posttest - Control.Posttest' is: {}.".format(round(sample_avg,10)))
# Out:
# sample average of 'Treated.Posttest - Control.Posttest' is: 3.0.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(5)
x = np.arange(1, 101)
print (x)
y = 20 + 3 * x + np.random.normal(0, 60, 100)
plt.plot(x, y, "o")


# draw vertical line from (0,0) to (100, 100)
#plt.plot([0, 0], [100, 100], 'k-')

# draw diagonal line from (70, 90) to (90, 200)
plt.plot([0, 100], [0, 400], 'k-')

plt.show()
